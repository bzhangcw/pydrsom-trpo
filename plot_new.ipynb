# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x = np.linspace(0, 1000, 1000)

# %%
trpo = pd.read_csv('./data/local/experiment/trpo_pendulum_40/progress.csv')
plt.plot(trpo["Evaluation/AverageDiscountedReturn"], label='trpo')

vpg = pd.read_csv('./data/local/experiment/trpo_pendulum_41/progress.csv')
plt.plot(vpg["Evaluation/AverageDiscountedReturn"], label='vpg')

df_drsom = pd.read_csv('./drsom_test_46/progress.csv')
plt.plot(df_drsom["Evaluation/AverageDiscountedReturn"], label='drsom-g-m')

plt.legend()

plt.savefig('drsom-trpo-vpg-100.pdf')

# %%
df_drsom_1 = pd.read_csv('./drsom_test_48/progress.csv')
plt.plot(df_drsom_1["Evaluation/AverageDiscountedReturn"], label='drsom-g-m')

df_drsom_2 = pd.read_csv('./drsom_test_52/progress.csv')
plt.plot(df_drsom_2["Evaluation/AverageDiscountedReturn"], label='drsom-g-Hg')

df_drsom_3 = pd.read_csv('./drsom_test_53/progress.csv')
plt.plot(df_drsom_3["Evaluation/AverageDiscountedReturn"], label='drsom-g-Hg-HHg')

plt.legend()

plt.savefig('drsom-comparison.pdf')
