# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x = np.linspace(0, 1000, 1000)

# %%
# df_drsom_1 = pd.read_csv('./drsom_test_4/progress.csv')
# plt.plot(x, df_drsom_1["Evaluation/AverageDiscountedReturn"], label='drsom-1')

df_drsom_2 = pd.read_csv('./drsom_test_36/progress.csv')
plt.plot(df_drsom_2["Evaluation/AverageDiscountedReturn"], label='drsom-2')


df_drsom_4 = pd.read_csv('./drsom_test_37/progress.csv')
plt.plot(df_drsom_4["Evaluation/AverageDiscountedReturn"], label='drsom-4')

trpo = pd.read_csv('./data/local/experiment/trpo_pendulum_4/progress.csv')

plt.plot(trpo["Evaluation/AverageDiscountedReturn"], label='trpo')


plt.legend()
